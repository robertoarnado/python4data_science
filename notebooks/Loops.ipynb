# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0101ENSkillsNetwork1005-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# <h3>For Loops </h3>

# %% [markdown]
# Use loops to print out the elements in the list <code>A</code>:

# %%
A = [3,4,5]
for i in A:
    print(i)

# %%
frutas = ["naranja", "manzana", "mango"]
cantidades = [10, 40, 59]
for fruta in frutas:
    print(fruta)
    print(f"la fruta con mayor exportacion es el {fruta}")
    
for cantidad in cantidades:
    print(f"se exporto {cantidad} kg de manzana en en 2020")
    
# Recorriendo una dos lista con la funcion zip

for cantidad, fruta in zip(cantidades, frutas):
    print (f"se proceso la {fruta} en total:")
    print (f"{cantidad}  kg en el mes de ocutubre" )
# Out:
# naranja
# la fruta con mayor exportacion es el naranja
# manzana
# la fruta con mayor exportacion es el manzana
# mango
# la fruta con mayor exportacion es el mango
# se exporto 10 kg de manzana en en 2020
# se exporto 40 kg de manzana en en 2020
# se exporto 59 kg de manzana en en 2020
# se proceso la naranja en total:
# 10  kg en el mes de ocutubre
# se proceso la manzana en total:
# 40  kg en el mes de ocutubre
# se proceso la mango en total:
# 59  kg en el mes de ocutubre

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# for i in A:
#     print(i)
#
# ```
#
# </details>

# %% [markdown]
# <h3>While Loops</h3>

# %% [markdown]
# Find the value of <code> x </code> that will print out the sequence <code> 1,2,..,10 </code>:

# %%
x=11
y=1
while(y != x):
    print(y)
    y=y+1

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# x = 11
#
# ```
#
# </details>

# %% [markdown]
# <hr>
#
# <h3 align="center"> © IBM Corporation 2020. All rights reserved. <h3/>
