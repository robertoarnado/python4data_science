# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0101ENSkillsNetwork1005-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# You will need the class Car for the next exercises. The class Car has four data attributes: make, model, colour and number of owners (owner_number). The method <code> car_info() </code>  prints out the data attributes and the method <code>sell()</code> increments the number of owners by 1.

# %%
class Car(object):
    def __init__(self,make,model,color):
        self.make=make;
        self.model=model;
        self.color=color;
        self.owner_number=0 
    def car_info(self):
        print("make: ",self.make)
        print("model:", self.model)
        print("color:",self.color)
        print("number of owners:",self.owner_number)
    def sell(self):
        self.owner_number=self.owner_number+1

# %% [markdown]
# <h3> Create a Car Object </h3>

# %% [markdown]
# Create a <code> Car </code> object "my_car" with the given data attributes:

# %%
make="BMW"
model="M3"
color="red"
my_car = Car(make,model,color)
my_car

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# my_car = Car(make,model,color)
#
# ```
#
# </details>

# %% [markdown]
# <h3> Data Attributes </h3>

# %% [markdown]
# Use the method `car_info()` to print out the data attributes.

# %%
my_car.car_info()

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# my_car.car_info()
#
# ```
#
# </details>

# %% [markdown]
# <h3> Methods  </h3>

# %% [markdown]
# Call the method <code> sell() </code> in the loop, then call the method <code> car_info()</code> again

# %%
for i in range(5):
    my_car.sell()
my_car.car_info()

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# for i in range(5):
#     my_car.sell()
#
# my_car.car_info()
#
# ```
#
# </details>

# %%
class cultivos(object):
    def __init__(self, permanente, transitorio):
        self.permanente = permanente;
        self.transitorio = transitorio;
    def cultivos_info(self):
        print("cultivo permanente", self.permanente)
        print("cultivo transitorio", self.transitorio)

# %%
permanente = "cafe"
transitorio = "maiz"
tipo_de_cultivo  = cultivos(permanente, transitorio)
tipo_de_cultivo

# %%
tipo_de_cultivo.cultivos_info()

# %% [markdown]
# <h2>Table of Contents</h2>
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#     <ul>
#         <li>
#             <a href="#Introduction-to-Classes-and-Objects">Introduction to Classes and Objects</a>
#             <ul>
#                 <li><a href="#Creating-a-class">Creating a class</a></li>
#                 <li><a href="#Instances-of-a-Class:-Objects-and-Attributes">Instances of a Class: Objects and Attributes</a></li>
#                 <li><a href="#Methods">Methods</a></li>
#             </ul>
#         </li>
#         <li><a href="#Creating-a-class">Creating a class</a></li>
#         <li><a href="#Creating-an-instance-of-a-class-Circle">Creating an instance of a class Circle</a></li>
#         <li><a href="#The-Rectangle-Class">The Rectangle Class</a></li>
#     </ul>
#
# </div>
#
# <hr>

# %% [markdown]
# ## Introduction to Classes and Objects

# %% [markdown]
# ### Creating a Class

# %% [markdown]
# The first step in creating a class is giving it a name. In this notebook, we will create two classes: Circle and Rectangle. We need to determine all the data that make up that class, which we call <em>attributes</em>. Think about this step as creating a blue print that we will use to create objects. In figure 1 we see two classes, Circle and Rectangle. Each has their attributes, which are variables. The class Circle has the attribute radius and color, while the Rectangle class has the attribute height and width. Let’s use the visual examples of these shapes before we get to the code, as this will help you get accustomed to the vocabulary.

# %% [markdown]
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/labs/Module%203/images/ClassesClass.png" width="500">

# %% [markdown]
# <i>Figure 1: Classes circle and rectangle, and each has their own attributes. The class Circle has the attribute radius and colour, the class Rectangle has the attributes height and width.</i>

# %% [markdown]
# ### Instances of a Class: Objects and Attributes

# %% [markdown]
# An instance of an object is the realisation of a class, and in Figure 2 we see three instances of the class circle. We give each object a name: red circle, yellow circle, and green circle. Each object has different attributes, so let's focus on the color attribute for each object.

# %% [markdown]
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/labs/Module%203/images/ClassesObj.png" width="500">

# %% [markdown]
# <i>Figure 2: Three instances of the class Circle, or three objects of type Circle.</i>

# %% [markdown]
# The colour attribute for the red Circle is the colour red, for the green Circle object the colour attribute is green, and for the yellow Circle the colour attribute is yellow.

# %% [markdown]
# ### Methods

# %% [markdown]
# Methods give you a way to change or interact with the object; they are functions that interact with objects. For example, let’s say we would like to increase the radius of a circle by a specified amount. We can create a method called **add_radius(r)** that increases the radius by **r**. This is shown in figure 3, where after applying the method to the "orange circle object", the radius of the object increases accordingly. The “dot” notation means to apply the method to the object, which is essentially applying a function to the information in the object.

# %% [markdown]
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/labs/Module%203/images/ClassesMethod.png" width="500">

# %% [markdown]
# <i>Figure 3: Applying the method “add_radius” to the object orange circle object.</i>

# %% [markdown]
# ## Creating a Class

# %% [markdown]
# Now we are going to create a class Circle, but first, we are going to import a library to draw the objects:

# %%
# Import the library

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# The first step in creating your own class is to use the <code>class</code> keyword, then the name of the class as shown in Figure 4. In this course the class parent will always be object:

# %% [markdown]
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/labs/Module%203/images/ClassesDefine.png" width="400">

# %% [markdown]
# <i>Figure 4: Creating a class Circle.</i>

# %% [markdown]
# The actual object is shown below. We include the method <code>drawCircle</code> to display the image of a circle. We set the default radius to 3 and the default colour to blue:

# %%
# create a class of circle 
class Circle(object):
    
    #constructor method
    def __init__(self, radius, color):
        self.radius = radius
        self.color = color

    # method 
    def add_radius(self, r):
        self.radius = self.radius + r
        return (self.radius)
    
    #method
    def draw_circle(self):
        plt.gca().add_patch(plt.Circle((0, 0), self.radius, color=self.color))
        plt.axis('scaled')
        plt.show()

# %% [markdown]
# ## Creating an instance of a class Circle

# %% [markdown]
# Let's create an instance of the class Circle called <code> my_circle </code> with a radius of 4 and colour yellow:

# %%
# create an object of the class
yellow_circle = Circle(2, 'yellow')
yellow_circle.draw_circle()

# %%
# crating anothe object of the class
blue_circle = Circle(5, "blue")
blue_circle.draw_circle()

# %% [markdown]
# We can use the <code>dir</code> command to get a list of the object's methods. Many of them are default Python methods.

# %%
# find out the methods can be used on the object 
dir(blue_circle)

# %% [markdown]
# We can look at the date attributes of the object:

# %%
# Print the object attributes radius
blue_circle.radius

# %%
# Print the object attributes color
blue_circle.color

# %% [markdown]
# We can change the object attributes directly. For example, we can change the radius and colour of the circle object:

# %%
# Set the attributes radius:
blue_circle.radius = 10
blue_circle.radius

# %% [markdown]
# We can draw the object by using method <code> draw_circle()</code>:

# %%
# Call the method draw_circle():
blue_circle.draw_circle()

# %% [markdown]
# We can increase the radius of the circle by applying the method <code>add_radius()</code>. Let's increases the radius by 2 and then by 5:

# %%
# Use method to change the object attribute radius

print('Radius of object:',yellow_circle.radius)
yellow_circle.add_radius(2)
print('Radius of object of after applying the method add_radius(2):',yellow_circle.radius)
yellow_circle.add_radius(5)
print('Radius of object of after applying the method add_radius(5):',yellow_circle.radius)

# %% [markdown]
# Let’s create a blue circle. As the default colour is blue, all we have to do is specify what the radius is:

# %%
# Create a blue circle with a given radius
blue_circle = Circle(100, 'blue')

# %% [markdown]
# As before, we can access the attributes of the instance of the class by using the dot notation:

# %%
# Print the object attributes radius color
blue_circle.radius

# %% [markdown]
# We can can draw the object  by using the method <code> draw_circle()</code>:

# %%
# call the method draw_circle()
blue_circle.draw_circle()

# %% [markdown]
# <h2> The Rectangle Class </h2>

# %% [markdown]
# Let's create a class rectangle with attributes height and width, and a method to draw the rectangle.

# %%
# Create a new rectangle class for creating rectangle objects
class Rectangle(object):
    #constructor method
    def __init__(self, height, width, color):
        self.height = height
        self.width = width
        self.color = color
    # method
    def draw_rectangle(self):
        plt.gca().add_patch(plt.Rectangle((0, 0), self.width, self.height, fc= self.color))
        plt.axis("scaled")
        plt.show()

# %% [markdown]
# Let’s create the object <code>skinny_blue_rectangle</code> of type Rectangle. Its width will be 2 and height will be 3, and the color will be blue:

# %%
skinny_blue_rectangle = Rectangle(3, 2, "blue")

# %% [markdown]
# As before we can access the attributes of the instance of the class by using the dot notation:

# %%
# Print the object attributes hight
skinny_blue_rectangle.height

# %%
# Print the object attributes color
skinny_blue_rectangle.color

# %%
# Print the object attributes radius
skinny_blue_rectangle.width

# %% [markdown]
# We can draw the object:

# %%
# Use the draw_rectangle method to draw the rectangle
skinny_blue_rectangle.draw_rectangle()

# %% [markdown]
# <center>
#
# # Scenario: Car dealership's inventory management system
#
# </center>

# %% [markdown]
# You are working on a Python program to simulate a car dealership's inventory management system. The system aims to model cars and their attributes accurately.

# %% [markdown]
# ### Task-1. You are tasked with creating a Python program to represent vehicles using a class. Each car should have attributes for maximum speed and mileage.

# %%
# Python program to represent vehicles using a class. Each car should be have attributes for maximum speed and mileage.

class Vehicle(object):
    def __init__(self, max_speed, mileage):
        self.max_speed = max_speed
        self.mileage = mileage

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
#
# class Vehicle:
#     def __init__(self, max_speed, mileage):
#         self.max_speed = max_speed
#         self.mileage = mileage
#
# ```
#
# </details>

# %% [markdown]
# ### Task-2. Update the class with the default color for all vehicles," white".

# %%
# Update the class with the default color for all vehicles, "white".
class Vehicle(object):
    color = 'white'
    def __init__(self, max_speed, mileage):
        self.max_speed = max_speed
        self.mileage = mileage

# %% [markdown]
# ### Task-3. Additionally, you need to create methods in the Vehicle class to assign seating capacity to a vehicle.

# %%
# Create a methods in the vehicle class to assign seating capacity to a vehicle
class Vehicle(object):
    color = 'white'
    def __init__(self, max_speed, mileage):
        self.max_speed = max_speed
        self.mileage = mileage
        self.seating_capacity = None
    def assign_seating_capacity(self, capacity):
        self.seating_capacity = capacity

# %% [markdown]
# ### Task-4. Create a method to display all the properties of an object of the class.

# %%
# Create a method to display all properties of an object of the class
class vehicle(object):
    color = 'white'
    def __init__(self, max_speed, mileage):
        self.max_speed = max_speed
        self.mileage = mileage
        self.seating_capacity = None
        
    def assign_seating_capacity(self, seating_capacity):
        self.seating_capacity = seating_capacity
    def display_properties(self):
        print("properties of the vehicle:")
        print("color:", self.color)
        print("max_speed:", self.max_speed)
        print("mileage:", self.mileage)
        print("seating_capacity:", self.seating_capacity)

# %%
# create an object of the vehicle class and display all the properties
my_vehicle = vehicle(240, 18)
my_vehicle.display_properties()
# Out:
# properties of the vehicle:
# color: white
# max_speed: 240
# mileage: 18
# seating_capacity: None

# %% [markdown]
# ### Task-5. Additionally, you need to create two objects of the Vehicle class object that should have a max speed of 200kmph and mileage of 20kmpl with five seating capacities, and another car object should have a max speed of 180kmph and mileage of 25kmpl with four seating capacities.

# %%
# create two objects of the vehicle class object that should have max speed of 200 km/h and mileage Pf 20 km/h with five seating capacities, and anothe object should have max speed of  180 km/h and 25 kmpl with four seatin capacities
my_vehicle1 = vehicle(200, 20)
my_vehicle1.assign_seating_capacity(5)
my_vehicle2 = vehicle(180, 25)
my_vehicle2.assign_seating_capacity(4)

# %%
# show the properties of the two vehicles
my_vehicle1.display_properties()
# Out:
# properties of the vehicle:
# color: white
# max_speed: 200
# mileage: 20
# seating_capacity: 5
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
